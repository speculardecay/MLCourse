# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\ML\Intro to ML Course\Week4\Assignment\breast cancer.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
word_to_num = {'B': 0, 'M': 1}
df['diagnosisId'] = df['diagnosis'].map(word_to_num)
df.drop(["Unnamed: 32"], axis=1, inplace=True)
df.drop(["id"], axis=1, inplace=True)
df.drop(columns=df.filter(like='_se').columns, inplace=True)
df.drop(columns=df.filter(like='_worst').columns, inplace=True)
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean  diagnosisId
# 0         0.2419                 0.07871            1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   diagnosis               569 non-null    object
#  1   radius_mean             569 non-null    float64
#  2   texture_mean            569 non-null    float64
#  3   perimeter_mean          569 non-null    float64
#  4   area_mean               569 non-null    float64
#  5   smoothness_mean         569 non-null    float64
#  6   compactness_mean        569 non-null    float64
#  7   concavity_mean          569 non-null    float64
#  8   concave points_mean     569 non-null    float64
#  9   symmetry_mean           569 non-null    float64
#  10  fractal_dimension_mean  569 non-null    float64
#  11  diagnosisId             569 non-null    int64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 53.5+ KB

# %%
sns.jointplot(x="fractal_dimension_mean", y="diagnosis", data=df)

# %%
df.drop(["texture_mean","area_mean","smoothness_mean","concavity_mean","fractal_dimension_mean"], axis=1, inplace=True)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  perimeter_mean  compactness_mean  \
# 0         M        17.99          122.80           0.27760
# 1         M        20.57          132.90           0.07864
# 2         M        19.69          130.00           0.15990
# 3         M        11.42           77.58           0.28390
# 4         M        20.29          135.10           0.13280
#
#    concave points_mean  symmetry_mean  diagnosisId
# 0              0.14710         0.2419            1
# 1              0.07017         0.1812            1
# 2              0.12790         0.2069            1
# 3              0.10520         0.2597            1
# 4              0.10430         0.1809            1

# %%
# Find null (or none) values
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <Axes: >

# %%
#model
# Drop null values
df.dropna(inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[["radius_mean", "perimeter_mean", "compactness_mean", "concave points_mean","symmetry_mean"]]
y = df["diagnosis"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.4, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter=5000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=5000)

# %%
predictions = model.predict(X_test)

# %%
print(predictions)
# Out:
# ['B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'B'
#  'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B'
#  'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'M' 'B' 'B'
#  'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'B' 'M'
#  'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'B'
#  'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'M' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'M' 'B' 'B'
#  'M' 'B' 'B' 'B' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'B']

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.91      0.96      0.93       148
#            M       0.92      0.82      0.87        80
#
#     accuracy                           0.91       228
#    macro avg       0.91      0.89      0.90       228
# weighted avg       0.91      0.91      0.91       228
