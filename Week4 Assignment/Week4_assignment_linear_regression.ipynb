# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"D:\ML\Intro to ML Course\Week4\Assignment\CarPrice_Assignment.csv")
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
sns.set_palette("GnBu_d")
sns.set_style("whitegrid")

# %%
sns.jointplot(x="highwaympg", y="price", data=df)

# %%
df.drop(["fueltype","symboling","aspiration","doornumber","carbody","carheight","enginetype","fuelsystem","compressionratio","peakrpm","wheelbase"], axis=1, inplace=True)

# %%
df['CarName'] = df['CarName'].str.split(' ').str[0]
df['CarName'] = df['CarName'].str.lower()

# %%
unique_values = df['CarName'].unique()
print(unique_values)
# Out:
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'maxda' 'mazda' 'buick' 'mercury' 'mitsubishi' 'nissan' 'peugeot'
#  'plymouth' 'porsche' 'porcshce' 'renault' 'saab' 'subaru' 'toyota'
#  'toyouta' 'vokswagen' 'volkswagen' 'vw' 'volvo']

# %%
df['CarNameId'] = pd.factorize(df['CarName'])[0]
df['drivewheelId'] = pd.factorize(df['drivewheel'])[0]
df['enginelocationId'] = pd.factorize(df['enginelocation'])[0]
df.head()
# Out:
#    car_ID      CarName drivewheel enginelocation  carlength  carwidth  \
# 0       1  alfa-romero        rwd          front      168.8      64.1
# 1       2  alfa-romero        rwd          front      168.8      64.1
# 2       3  alfa-romero        rwd          front      171.2      65.5
# 3       4         audi        fwd          front      176.6      66.2
# 4       5         audi        4wd          front      176.6      66.4
#
#    curbweight cylindernumber  enginesize  boreratio  stroke  horsepower  \
# 0        2548           four         130       3.47    2.68         111
# 1        2548           four         130       3.47    2.68         111
# 2        2823            six         152       2.68    3.47         154
# 3        2337           four         109       3.19    3.40         102
# 4        2824           five         136       3.19    3.40         115
#
#    citympg  highwaympg    price  CarNameId  drivewheelId  enginelocationId
# ...

# %%
word_to_num = {
    'zero': 0, 'one': 1, 'two': 2, 'three': 3, 'four': 4, 
    'five': 5, 'six': 6, 'seven': 7, 'eight': 8, 'nine': 9
}
df['cylindernumber'] = df['cylindernumber'].map(word_to_num)

# %%
df.head()
# Out:
#    car_ID      CarName drivewheel enginelocation  carlength  carwidth  \
# 0       1  alfa-romero        rwd          front      168.8      64.1
# 1       2  alfa-romero        rwd          front      168.8      64.1
# 2       3  alfa-romero        rwd          front      171.2      65.5
# 3       4         audi        fwd          front      176.6      66.2
# 4       5         audi        4wd          front      176.6      66.4
#
#    curbweight  cylindernumber  enginesize  boreratio  stroke  horsepower  \
# 0        2548             4.0         130       3.47    2.68         111
# 1        2548             4.0         130       3.47    2.68         111
# 2        2823             6.0         152       2.68    3.47         154
# 3        2337             4.0         109       3.19    3.40         102
# 4        2824             5.0         136       3.19    3.40         115
#
#    citympg  highwaympg    price  CarNameId  drivewheelId  enginelocationId
# ...

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap="viridis")
# Out:
# <Axes: >

# %%
df.dropna(axis=0,inplace=True)
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap="viridis")
# Out:
# <Axes: >

# %%
#sns.pairplot(df)

# %% [markdown]
# # Training Sets

# %%
df.head()
# Out:
#    car_ID      CarName drivewheel enginelocation  carlength  carwidth  \
# 0       1  alfa-romero        rwd          front      168.8      64.1
# 1       2  alfa-romero        rwd          front      168.8      64.1
# 2       3  alfa-romero        rwd          front      171.2      65.5
# 3       4         audi        fwd          front      176.6      66.2
# 4       5         audi        4wd          front      176.6      66.4
#
#    curbweight  cylindernumber  enginesize  boreratio  stroke  horsepower  \
# 0        2548             4.0         130       3.47    2.68         111
# 1        2548             4.0         130       3.47    2.68         111
# 2        2823             6.0         152       2.68    3.47         154
# 3        2337             4.0         109       3.19    3.40         102
# 4        2824             5.0         136       3.19    3.40         115
#
#    citympg  highwaympg    price  CarNameId  drivewheelId  enginelocationId
# ...

# %%
X = df[["CarNameId", "drivewheelId", "enginelocationId", "carlength","carwidth","curbweight","cylindernumber","enginesize","boreratio","stroke","horsepower","citympg","highwaympg"]]
y = df[["price"]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.4, random_state=42)

# %%
X_train
# Out:
#      CarNameId  drivewheelId  enginelocationId  carlength  carwidth  \
# 78          12             1                 0      157.3      64.4
# 46           6             0                 0      172.6      65.2
# 118         15             1                 0      157.3      63.8
# 146         20             1                 0      173.5      65.4
# 86          12             1                 0      172.4      65.4
# ..         ...           ...               ...        ...       ...
# 107         14             0                 0      186.7      68.4
# 14           2             0                 0      189.0      66.9
# 93          13             1                 0      170.2      63.8
# 180         21             0                 0      187.8      66.5
# 103         13             1                 0      184.6      66.5
#
#      curbweight  cylindernumber  enginesize  boreratio  stroke  horsepower  \
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Coef : ", linear_model.coef_)
# Out:
# Coef :  [[-1.07527062e+02 -1.04649790e+03  1.26460169e+04  7.21319108e+00
#    7.55909854e+02  3.00610013e+00  9.09559091e+01  8.33939436e+01
#   -3.03986063e+03 -2.70555335e+03  1.79785437e+01 -1.39616871e+01
#   -3.14204494e+01]]

# %%
predictions = linear_model.predict(X_test)

# %%
# Plot a graph that compares the y_test actual sample values
# to the result of the prediction from the fit using the same y_test samples
# A linear graph means the predictions are mostly correct
plt.scatter(y_test, predictions)
plt.xlabel("Y test")
plt.ylabel("Predicted Y")
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn import metrics

print("MAE", metrics.mean_absolute_error(y_test, predictions))
print("MSI", metrics.mean_squared_error(y_test, predictions))
# Square root of MSI
print("RMSE", np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE 2097.8361226718107
# MSI 9951676.051792694
# RMSE 3154.627720000047

# %%
sns.displot((y_test-predictions), bins=100, kde=True)
